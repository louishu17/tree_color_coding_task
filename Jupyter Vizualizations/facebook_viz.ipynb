# %%
#A file for final vizualizations
import nbformat
import pandas as pd 
import numpy as np 
import matplotlib as plot
from matplotlib import pyplot as plt
from nbconvert import HTMLExporter
from pandas import DataFrame
import seaborn as sns
from sklearn.cluster import KMeans
import tkinter as tk
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
import tkinter as tk
from tkinter import filedialog

# %%
#n = tufts, vassar. k = 5, 
correlated = [8.165989e+20, 8.168772e+20, 8.148340e+20, 8.177414e+20, 8.179528e+20, 8.152798e+20, 8.111885e+20, 8.174197e+20, 8.132137e+20, 8.138546e+20, 8.174404e+20, 8.126722e+20, 8.218140e+20, 8.115522e+20, 8.117085e+20, 8.157187e+20]
independent = [3.275436e+20, 3.255112e+20, 3.265434e+20, 3.264644e+20, 3.246201e+20, 3.255758e+20, 3.250893e+20, 3.253701e+20, 3.250656e+20, 3.261402e+20, 3.266744e+20, 3.263157e+20, 3.273046e+20, 3.250601e+20, 3.255938e+20]

list1 = ['ind' for x in range(16)]
list2 = ['corr' for x in range(17)]
sns.displot(correlated, color='blue', label="Independent").set(xlabel = 'statistic', ylabel = 'repetitions', title = 'Correlated')
sns.displot(independent, color='red', label="Independent").set(xlabel = 'statistic', ylabel = 'repetitions', title = 'Correlated')
sns.set_style("darkgrid", {'ytick.left' : True, 'xtick.bottom': True, 'axes.spines.left': True, 'grid.color': '1', 'axes.edgecolor': '0', 'axes.spines.right': False, "axes.facecolor": ".9"})
sns.set_context("talk")
sns.despine(right = True, top=True)
print(correlated)
independent
# Out:
# [8.165989e+20, 8.168772e+20, 8.14834e+20, 8.177414e+20, 8.179528e+20, 8.152798e+20, 8.111885e+20, 8.174197e+20, 8.132137e+20, 8.138546e+20, 8.174404e+20, 8.126722e+20, 8.21814e+20, 8.115522e+20, 8.117085e+20, 8.157187e+20]
# [3.275436e+20,
#  3.255112e+20,
#  3.265434e+20,
#  3.264644e+20,
#  3.246201e+20,
#  3.255758e+20,
#  3.250893e+20,
#  3.253701e+20,
#  3.250656e+20,
#  3.261402e+20,
#  3.266744e+20,
#  3.263157e+20,
#  3.273046e+20,
#  3.250601e+20,
#  3.255938e+20]

# %%
#changing s centered k = 4 n = 1000 t = 100
list1 = [18.4015005706668, 136.5231142912004, -251.84482507066613, 3173.965368381994, 3933.3840020240027, -638.8296461312007, 64.95271007013679, -190.66040221013392, -195.39773920239966, 313.8826518186665]
list2 = [80.00594147266686, 1164.9170804896016, 774.9320839125318, 5928.001355400528, 7254.523697414528, 410.4068249898695, 835.2767683488001, 855.791062351599, 721.4640648030673, 290.3472286378679]
s_9 = np.arange(.1,1,.1)
s9_1 = pd.DataFrame(zip(s_9,list1), columns=['s','out'])
s9_2 = pd.DataFrame(zip(s_9,list2), columns=['s','out'])
sns.scatterplot(data = s9_1, x = 's', y = 'out', color='black', label='run 1').set(xlabel = 's', ylabel = 'Statistic', title = 'Statistic as s changes')
sns.scatterplot(data = s9_2, x = 's', y = 'out', color='yellow', label='run 2').set(xlabel = 's', ylabel = 'Statistic', title = 'Statistic as s changes')
sns.set_style("darkgrid", {'ytick.left' : True, 'xtick.bottom': True, 'axes.spines.left': True, 'grid.color': '1', 'axes.edgecolor': '0', 'axes.spines.right': False, "axes.facecolor": ".9"})
sns.set_context("talk")
sns.despine(right = True, top=True)
sns.set_palette("PiYG", 10)
print(s9_1)
print(s9_2)
# Out:
#      s          out
# 0  0.1    18.401501
# 1  0.2   136.523114
# 2  0.3  -251.844825
# 3  0.4  3173.965368
# 4  0.5  3933.384002
# 5  0.6  -638.829646
# 6  0.7    64.952710
# 7  0.8  -190.660402
# 8  0.9  -195.397739
#      s          out
# 0  0.1    80.005941
# 1  0.2  1164.917080
# 2  0.3   774.932084
# 3  0.4  5928.001355
# 4  0.5  7254.523697
# 5  0.6   410.406825
# 6  0.7   835.276768
# 7  0.8   855.791062
# 8  0.9   721.464065

# %%
#changing s centered k = 4 n = 1000 t = full
list1 = [60.64510154335779, 19.90299701346096, 140.32731698497733, 285.28024777944006, 939.3988680838279, 657.32713109564, 810.9105468978507, 915.4393737380256, 41.878449158497894]
list2 = [49.992251238586235, 55.76123872329852, 368.9997930025047, -143.6400013685976, 472.07360993157647, 3388.616370061384, 1085.5453242428553, 285.8046079839168, 1102.0324726127237]
list3 = [60.64510154335779, 19.90299701346096, 140.32731698497733, 285.28024777944006, 939.3988680838279, 657.32713109564, 810.9105468978507, 915.4393737380256, 41.878449158497894, 539.1113118412364]
s_9 = np.arange(.1,1,.1)
s_10 = np.arange(.1,1.1,.1)
s9_1 = pd.DataFrame(zip(s_9,list1), columns=['s','out'])
s9_2 = pd.DataFrame(zip(s_9,list2), columns=['s','out'])
s9_3 = pd.DataFrame(zip(s_10,list3), columns=['s','out'])
sns.scatterplot(data = s9_1, x = 's', y = 'out', color='red', label = 'run 1').set(xlabel = 's', ylabel = 'Statistic', title = 'Statistic as s changes')
sns.scatterplot(data = s9_2, x = 's', y = 'out', color='yellow', label = 'run 2').set(xlabel = 's', ylabel = 'Statistic', title = 'Statistic as s changes')
#sns.scatterplot(data = s9_3, x = 's', y = 'out', color='blue', label = 'run 3').set(xlabel = 's', ylabel = 'Statistic', title = 'Statistic as s changes')
sns.set_style("darkgrid", {'ytick.left' : True, 'xtick.bottom': True, 'axes.spines.left': True, 'grid.color': '1', 'axes.edgecolor': '0', 'axes.spines.right': False, "axes.facecolor": ".9"})
sns.set_context("talk")
sns.despine(right = True, top=True)
sns.set_palette("PiYG", 10)
print(s9_1)
print(s9_2)
print(s9_3)
# Out:
#      s         out
# 0  0.1   60.645102
# 1  0.2   19.902997
# 2  0.3  140.327317
# 3  0.4  285.280248
# 4  0.5  939.398868
# 5  0.6  657.327131
# 6  0.7  810.910547
# 7  0.8  915.439374
# 8  0.9   41.878449
#      s          out
# 0  0.1    49.992251
# 1  0.2    55.761239
# 2  0.3   368.999793
# 3  0.4  -143.640001
# 4  0.5   472.073610
# 5  0.6  3388.616370
# 6  0.7  1085.545324
# 7  0.8   285.804608
# 8  0.9  1102.032473
#      s         out
# 0  0.1   60.645102
# 1  0.2   19.902997
# 2  0.3  140.327317
# 3  0.4  285.280248
# 4  0.5  939.398868
# 5  0.6  657.327131
# 6  0.7  810.910547
# 7  0.8  915.439374
# 8  0.9   41.878449
# 9  1.0  539.111312

# %%
#Louis Fascia sim2 run 
'''
curve = True
Both = [4.75509e+06,1.89211e+07,5.8645e+06,6.41865e+06,9.05948e+06,6.53754e+06,7.37387e+06,7.89143e+06,6.24858e+06,1.87155e+06,5.13922e+06,6.45424e+06,3.5234e+06,6.4723e+06, 7.02223e+06, 6.96434e+06, 5.03053e+06, 6.26508e+06, 1.84697e+06, -4.61071e+07, -1.92234e+07, -1.01165e+07]
Northwestern = [5.06703e+06,6.30917e+06,5.39436e+06,6.47958e+06,5.26791e+06,6.0579e+06,7.62216e+06,5.95662e+06,5.07192e+06,5.67897e+06,6.13723e+09,5.43592e+06,6.22383e+06,2.56824e+10,4.64457e+09,6.51761e+06,4.70515e+06,6.70929e+06, 6.67893e+06, 5.20769e+06, 6.23353e+06, 4.88701e+06, 9.7773e+10]
UChicago = [3.46186e+07,6.99274e+06,8.67774e+06,8.29025e+06,7.36809e+07,2.05238e+10,5.34667e+06,9.39055e+08,3.63439e+08,8.20011e+06,4.14568e+06,6.15922e+06,6.54216e+06,6.66018e+06,7.55594e+06,6.86927e+06,6.78979e+06,5.43086e+06,8.41263e+09,6.84499e+06,6.08236e+06,8.27171e+06,4.69458e+06,5.00096e+06,5.30491e+08,1.50936e+10]
'''
'''
all = []
list = []
for x in range(len(Both)):
    list.append('Both')
for x in range(len(Northwestern)):
    list.append('Northwestern')
for x in range(len(UChicago)):
    list.append('Uchicago')
all = Both + Northwestern + UChicago
frame = pd.DataFrame()

frame['run'] = list
frame['school'] = all
'''
'''
sns.histplot(UChicago, label="UChicago", stat = "density", color='yellow')
sns.histplot(Both, label="Chicago", stat = "density", color='blue')
sns.histplot(Northwestern, label="Northwestern", stat = "density", color='red')
plt.legend()
sns.set_style("darkgrid", {'ytick.left' : True, 'xtick.bottom': True, 'axes.spines.left': True, 'grid.color': '1', 'axes.edgecolor': '0', 'axes.spines.right': False, "axes.facecolor": ".9"})
sns.set_context("talk")
sns.despine(right = True, top=True)
'''
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-0bd14edc552f> in <module>
#      19 frame['school'] = all
#      20 '''
# ---> 21 sns.histplot(Uchicago, label="Uchicago", stat = "density", color='yellow')
#      22 sns.histplot(Both, label="Chicago", stat = "density", color='blue')
#      23 sns.histplot(Northwestern, label="Northwestern", stat = "density", color='red')
#
# NameError: name 'Uchicago' is not defined

# %%
data = pd.read_csv('Similarity_Normalized.csv')
row = set()
data = data.loc[data['n'] == 7.0]
for x in data['File A']:
    row.add(x)
for x in data['File B']:
    row.add(x)
row = list(row)
matrix = np.zeros((98,98))
df = pd.DataFrame(matrix)
df.columns=row
df.index=row

for x in range(len(data)):
    df[data['File A'].iloc[x]][data['File B'].iloc[x]] = data['Similarity'].iloc[x]
    df[data['File B'].iloc[x]][data['File A'].iloc[x]] = data['Similarity'].iloc[x]
sns.heatmap(df.iloc[68:84,41:57], cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
df_two = df
  
kmeans = KMeans(n_clusters=3).fit(df_two)
centroids = kmeans.cluster_centers_

plt.scatter(df_two['Yale4'], df_two['Yale4'], c= kmeans.labels_.astype(float), s=50, alpha=0.5)
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', s=50)
plt.show()

# %%
df_two = df
root= tk.Tk()

canvas1 = tk.Canvas(root, width = 400, height = 300,  relief = 'raised')
canvas1.pack()

label1 = tk.Label(root, text='Clustering')
label1.config(font=('helvetica', 14))
canvas1.create_window(200, 25, window=label1)

label2 = tk.Label(root, text='Type Number of Clusters:')
label2.config(font=('helvetica', 8))
canvas1.create_window(200, 180, window=label2)

entry1 = tk.Entry (root) 
canvas1.create_window(200, 200, window=entry1)

label3 = tk.Label(root, text='Type School:')
label2.config(font=('helvetica', 8))
canvas1.create_window(200, 80, window=label3)

entry2 = tk.Entry (root)
canvas1.create_window(200, 100, window=entry2)

def choose_school ():
    global df_three
    df_three = entry2.get()
    
'''
browseSchools = tk.Button(text=" Choose School ", command=choose_school, bg='green', fg='white',  font=('helvetica', 10, 'bold'))
canvas1.create_window(200, 140, window=browseSchools)
'''

def getKMeans ():
    global df_three
    global numberOfClusters
    global df_three
    numberOfClusters = int(entry1.get())
    df_three = entry2.get()
    
    kmeans = KMeans(n_clusters=numberOfClusters).fit(df)
    centroids = kmeans.cluster_centers_
    
    label4 = tk.Label(root, text= centroids)
    #canvas1.create_window(200, 250, window=label4)
    
    figure1 = plt.Figure(figsize=(4,3), dpi=100)
    ax1 = figure1.add_subplot(111)
    ax1.scatter(df_two[df_three], df_two[df_three], c= kmeans.labels_.astype(float), s=50, alpha=0.5)
    ax1.scatter(centroids[:, 0], centroids[:, 1], c='red', s=50)
    scatter1 = FigureCanvasTkAgg(figure1, root) 
    scatter1.get_tk_widget().pack(side=tk.RIGHT, fill=tk.BOTH)
    
processButton = tk.Button(text=' Process k-Means ', command=getKMeans, bg='brown', fg='white', font=('helvetica', 10, 'bold'))
canvas1.create_window(200, 240, window=processButton)

root.mainloop()

# %%
#A file for final vizualizations
import nbformat
import pandas as pd 
import numpy as np 
import matplotlib as plot
from matplotlib import pyplot as plt
from nbconvert import HTMLExporter
from pandas import DataFrame
import seaborn as sns

# %%
# A vizualization to show time with changing K for simulation 1, 
# n = 40
sim1_k = pd.read_csv('/Users/kieranlele/PycharmProjects/Data+Networks/tree_color_coding_task-1/vis_sim1/data/sim1/k_1/test_csv.csv')
sns.lineplot(data = sim1_k, x = 'K', y = 'time').set(xlabel = 'K', ylabel = 'Time (Seconds)', title = 'Time as K Changes')
sns.set_style("darkgrid", {'ytick.left' : True, 'xtick.bottom': True, 'axes.spines.left': True, 'grid.color': '1', 'axes.edgecolor': '0', 'axes.spines.right': False, "axes.facecolor": ".9"})
sns.set_context("talk")
sns.despine(right = True, top=True)
sns.set_palette("PiYG", 10)
sim1_k
# Out:
#    K          rec           exp       err        time
# 0  2  1664.650794   1646.666667  0.010804    0.184296
# 1  3  4152.660819   4283.906250 -0.031605    2.480661
# 2  4  7947.594993   7896.096000  0.006480   45.874562
# 3  5  9625.663095  11106.423611 -0.153835  817.227591

# %%
# A vizualization to show time with changing n for simulation 1
# m = 3, 0 = .5, K = 2
sim1_n = pd.read_csv('/Users/kieranlele/PycharmProjects/Data+Networks/tree_color_coding_task-1/vis_sim1/data/sim1/n_3/inf_n_3.csv')
sns.scatterplot(data = sim1_n, x = 'n', y = 'time').set(xlabel = 'n', ylabel = 'Time (Seconds)', title = 'Time as N Changes')
sns.set_style("darkgrid", {'ytick.left' : True, 'xtick.bottom': True, 'axes.spines.left': True, 'grid.color': '1', 'axes.edgecolor': '0', 'axes.spines.right': False, "axes.facecolor": ".9"})
sns.set_context("talk")
sns.despine(right = True, top=True)
sns.set_palette("PiYG", 10)
sim1_n
# Out:
#     Unnamed: 0  m    n    p      H  K           rec           exp       err  \
# 0            0  3   10  0.5  0-1-1  2  1.631746e+01  2.000000e+01 -0.225681
# 1            1  3   20  0.5  0-1-1  2  1.887619e+02  1.900000e+02 -0.006559
# 2            2  3   30  0.5  0-1-1  2  6.516825e+02  6.766667e+02 -0.038338
# 3            3  3   40  0.5  0-1-1  2  1.617937e+03  1.646667e+03 -0.017757
# 4            4  3   50  0.5  0-1-1  2  3.143270e+03  3.266667e+03 -0.039257
# 5            5  3   60  0.5  0-1-1  2  5.701254e+03  5.703333e+03 -0.000365
# 6            6  3   70  0.5  0-1-1  2  9.140794e+03  9.123333e+03  0.001910
# 7            7  3   80  0.5  0-1-1  2  1.381552e+04  1.369333e+04  0.008844
# 8            8  3   90  0.5  0-1-1  2  1.990224e+04  1.958000e+04  0.016191
# 9            9  3  100  0.5  0-1-1  2  2.746683e+04  2.695000e+04  0.018816
# 10          10  3  110  0.5  0-1-1  2  3.579432e+04  3.597000e+04 -0.004908
# 11          11  3  120  0.5  0-1-1  2  4.670306e+04  4.680667e+04 -0.002218
# 12          12  3  130  0.5  0-1-1  2  6.081843e+04  5.962667e+04  0.019595
# 13          13  3  140  0.5  0-1-1  2  7.523260e+04  7.459667e+04  0.008453
# 14          14  3  150  0.5  0-1-1  2  9.103197e+04  9.188333e+04 -0.009352
# 15          15  3  160  0.5  0-1-1  2  1.082086e+05  1.116533e+05 -0.031834
# 16          16  3  170  0.5  0-1-1  2  1.336222e+05  1.340733e+05 -0.003376
# 17          17  3  180  0.5  0-1-1  2  1.579231e+05  1.593100e+05 -0.008782
# 18          18  3  190  0.5  0-1-1  2  1.872478e+05  1.875300e+05 -0.001507
# 19          19  3  200  0.5  0-1-1  2  2.167321e+05  2.189000e+05 -0.010002
# 20          20  3  210  0.5  0-1-1  2  2.511955e+05  2.535867e+05 -0.009519
# 21          21  3  220  0.5  0-1-1  2  2.932352e+05  2.917567e+05  0.005042
# 22          22  3  230  0.5  0-1-1  2  3.338577e+05  3.335767e+05  0.000842
# 23          23  3  240  0.5  0-1-1  2  3.787342e+05  3.792133e+05 -0.001265
# 24          24  3  250  0.5  0-1-1  2  4.311850e+05  4.288333e+05  0.005454
# 25          25  3  260  0.5  0-1-1  2  4.791897e+05  4.826033e+05 -0.007124
# 26          26  3  270  0.5  0-1-1  2  5.390343e+05  5.406900e+05 -0.003072
# 27          27  3  280  0.5  0-1-1  2  6.050266e+05  6.032600e+05  0.002920
# 28          28  3  290  0.5  0-1-1  2  6.670655e+05  6.704800e+05 -0.005119
# 29          29  3  300  0.5  0-1-1  2  7.434852e+05  7.425167e+05  0.001303
# 30          30  3  310  0.5  0-1-1  2  8.190073e+05  8.195367e+05 -0.000646
# 31          31  3  320  0.5  0-1-1  2  9.025301e+05  9.017067e+05  0.000912
# 32          32  3  330  0.5  0-1-1  2  9.892950e+05  9.891933e+05  0.000103
# 33          33  3  340  0.5  0-1-1  2  1.081660e+06  1.082163e+06 -0.000466
# 34          34  3  350  0.5  0-1-1  2  1.171158e+06  1.180783e+06 -0.008219
# 35          35  3  360  0.5  0-1-1  2  1.277933e+06  1.285220e+06 -0.005702
# 36          36  3  370  0.5  0-1-1  2  1.408691e+06  1.395640e+06  0.009265
# 37          37  3  380  0.5  0-1-1  2  1.511611e+06  1.512210e+06 -0.000396
# 38          38  3  390  0.5  0-1-1  2  1.638449e+06  1.635097e+06  0.002046
# 39          39  3  400  0.5  0-1-1  2  1.770869e+06  1.764467e+06  0.003616
# 40          40  3  410  0.5  0-1-1  2  1.899655e+06  1.900487e+06 -0.000438
# 41          41  3  420  0.5  0-1-1  2  2.040358e+06  2.043323e+06 -0.001453
# 42          42  3  430  0.5  0-1-1  2  2.188037e+06  2.193143e+06 -0.002334
# 43          43  3  440  0.5  0-1-1  2  2.353004e+06  2.350113e+06  0.001228
# 44          44  3  450  0.5  0-1-1  2  2.518390e+06  2.514400e+06  0.001584
# 45          45  3  460  0.5  0-1-1  2  2.674963e+06  2.686170e+06 -0.004190
# 46          46  3  470  0.5  0-1-1  2  2.865161e+06  2.865590e+06 -0.000150
# 47          47  3  480  0.5  0-1-1  2  3.055449e+06  3.052827e+06  0.000858
# 48          48  3  490  0.5  0-1-1  2  3.226052e+06  3.248047e+06 -0.006818
# 49          49  3  500  0.5  0-1-1  2  3.438596e+06  3.451417e+06 -0.003728
#
#          time
# 0    0.049757
# 1    0.066475
# 2    0.127847
# 3    0.213036
# 4    0.278803
# 5    0.385194
# 6    0.527593
# 7    0.705194
# 8    0.873497
# 9    1.088367
# 10   1.333187
# 11   1.876459
# 12   2.021375
# 13   2.314141
# 14   2.598383
# 15   2.967549
# 16   3.411099
# 17   3.837747
# 18   4.162737
# 19   4.625466
# 20   5.104791
# 21   5.799004
# 22   6.379626
# 23   7.098099
# 24   7.739096
# 25   8.474045
# 26   9.031939
# 27   9.954824
# 28  10.217944
# 29  11.084450
# 30  12.872047
# 31  15.979648
# 32  15.096002
# 33  14.330258
# 34  15.375347
# 35  16.684767
# 36  17.759051
# 37  18.417305
# 38  20.271865
# 39  20.779807
# 40  21.409061
# 41  22.975350
# 42  23.836183
# 43  26.047043
# 44  28.619962
# 45  29.915724
# 46  29.616209
# 47  30.815515
# 48  37.650189
# 49  40.455441

# %%
# A vizualization to show changing error for simulation 1
# m = 3, 0 = .5, K = 2
sim1_n = pd.read_csv('/Users/kieranlele/PycharmProjects/Data+Networks/tree_color_coding_task-1/vis_sim1/data/sim1/n_3/inf_n_3.csv')
sim1_n['err'] = sim1_n['err'].abs()
sim1_n = sim1_n[sim1_n['err'] < .15]
sns.scatterplot(data = sim1_n, x = 'n', y = 'err').set(xlabel = 'n', ylabel = 'Error', title = 'Error as N Changes')
sns.set_style("darkgrid", {'ytick.left' : True, 'xtick.bottom': True, 'axes.spines.left': True, 'grid.color': '1', 'axes.edgecolor': '0', 'axes.spines.right': False, "axes.facecolor": ".9"})
sns.set_context("talk")
sns.despine(right = True, top=True)
sns.set_palette("PiYG", 10)

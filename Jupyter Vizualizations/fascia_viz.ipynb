# %%
#A file for final vizualizations
import nbformat
import pandas as pd 
import numpy as np 
import matplotlib as plot
from matplotlib import pyplot as plt
from nbconvert import HTMLExporter
from pandas import DataFrame
import seaborn as sns

# %%
# A vizualization to show changing error for simulation 1
# m = 20, t = 100 color iterations, p = 0.01 n = 100
output = pd.DataFrame([3.255983e-002
, 1.920137e-002
, -1.943987e-003
, 9.551657e-003
, 1.495800e-002
, 1.271853e-002
, 2.204942e-002
, -3.229336e-002
, -5.634508e-003
, -1.670269e-003
, 1.764530e-002
, -1.178478e-002
, 8.213502e-003
, 3.318197e-002
, 6.644646e-004
, -1.630426e-002
, -7.475692e-003
, 1.458314e-003
, 2.811384e-002
, -1.583873e-002], columns={'output'})

sns.histplot(output, color='blue', label="n = 100").set(xlabel = 'statistic', ylabel = 'count')
plt.legend()
sns.set_style("darkgrid", {'ytick.left' : True, 'xtick.bottom': True, 'axes.spines.left': True, 'grid.color': '1', 'axes.edgecolor': '0', 'axes.spines.right': False, "axes.facecolor": ".9"})
sns.set_context("talk")
sns.despine(right = True, top=True)

# %%
# A vizualization to show changing error for simulation 1
# m = 20, t = 100 color iterations, p = 0.01 n = 500
output = pd.DataFrame([7.778195e+000
, 2.852669e-001
, 1.207549e+000
, -7.796647e+000
, -8.655259e-001
, -6.314849e+000
, 5.623679e-001
, 3.976210e+000
, 3.177075e+000
, 6.702350e+000
, -1.028220e+001
, 7.056719e+000
, -6.999649e+000
, 3.278164e+000
, -5.326166e-003
, 5.687077e+000
, 3.579705e+000
, 1.058424e+001
, -7.457465e+000
, -1.155478e+001], columns={'output'})

sns.histplot(output, color='blue', label="n = 500").set(xlabel = 'statistic', ylabel = 'count')
plt.legend()
sns.set_style("darkgrid", {'ytick.left' : True, 'xtick.bottom': True, 'axes.spines.left': True, 'grid.color': '1', 'axes.edgecolor': '0', 'axes.spines.right': False, "axes.facecolor": ".9"})
sns.set_context("talk")
sns.despine(right = True, top=True)

# %%
# A vizualization to show changing error for simulation 1
# m = 20, t = 100 color iterations, p = 0.01 n = 500
output = pd.DataFrame([-4.533549e+001
, 5.158483e+001
, -1.543742e+002
, -4.718890e+001
, 1.503145e+001
, -8.991785e+001
, -7.719870e+001
, 8.418680e+001
, 1.018849e+002
, -9.715608e+001
, 1.296307e+001
, 4.811054e+001
, -2.673011e+002
, 4.410260e+001
, 9.282396e+001
, 1.507292e+002
, 1.646382e+002
, -3.472727e+001
, 1.387799e+002
, -7.542310e+001], columns={'output'})

sns.histplot(output, color='blue', label="n = 1000").set(xlabel = 'statistic', ylabel = 'count')
plt.legend()
sns.set_style("darkgrid", {'ytick.left' : True, 'xtick.bottom': True, 'axes.spines.left': True, 'grid.color': '1', 'axes.edgecolor': '0', 'axes.spines.right': False, "axes.facecolor": ".9"})
sns.set_context("talk")
sns.despine(right = True, top=True)

# %%
#Louis Fascia sim2 run 
curve = True
list1 = [9.927497e-03, 7.464170e-01, 1.965038e-01, 2.275122e-01, 1.775988e-01, 3.671960e-01, 8.823285e-03, 2.730537e-01, 1.676764e-01, 7.045566e-01, 2.524590e-01, 2.914863e-01, 2.427776e-01, 3.195200e-01, -9.023725e-03, 3.471483e-01, 1.910597e-01, -2.394075e-03, 4.037732e-01, 1.238983e-01]
list2 = [-1.391901e-01, -1.174616e-01, 3.015944e-02, 4.093012e-01, -7.448949e-02, -1.327569e-01, 8.673814e-03, -3.709282e-02, -7.016357e-02, -1.677978e-01, 1.209628e-01, 2.676929e-02, -6.179662e-02, -2.210237e-01, -3.013907e-01, -8.225711e-02, -4.918706e-03, 1.313920e-01, 7.409446e-02, 3.050592e-02]

sns.histplot(list1, color='blue', label='Correlated', stat = "density")
sns.histplot(list2, color='yellow', label="Independent", stat = "density").set(xlabel = 'Statistic', ylabel = 'repetitions', title = 'fascia runs')
plt.legend()
sns.set_style("darkgrid", {'ytick.left' : True, 'xtick.bottom': True, 'axes.spines.left': True, 'grid.color': '1', 'axes.edgecolor': '0', 'axes.spines.right': False, "axes.facecolor": ".9"})
sns.set_context("talk")
sns.despine(right = True, top=True)

# %%
list2 = [1.194061e+06, 2.042968e+06, 1.243210e+06, 1.076174e+06, 1.538165e+06, 8.489135e+05, -8.128914e+04, 1.625458e+06, 1.083790e+06, 5.307100e+05, 5.232488e+05, 3.079316e+06, 1.313527e+06, 1.957674e+06, 3.740099e+05, 2.786045e+06, 2.191609e+06, 1.499911e+06, 9.289754e+05, 9.576632e+05]

sns.histplot(list1, color='pink', label='Correlated', stat = "density")
sns.histplot(list2, color='black', label="Independent", stat = "density").set(xlabel = 'Statistic', ylabel = 'repetitions', title = 'fascia runs')
plt.legend()
sns.set_style("darkgrid", {'ytick.left' : True, 'xtick.bottom': True, 'axes.spines.left': True, 'grid.color': '1', 'axes.edgecolor': '0', 'axes.spines.right': False, "axes.facecolor": ".9"})
sns.set_context("talk")
sns.despine(right = True, top=True)

# %%
# K=7 p = 0.1
curve = True
list1 = [2.939768e+12, 3.251806e+11, 6.161943e+12, -1.560056e+12, 2.332171e+12, 2.651191e+12, 1.212441e+13, 2.457178e+12, -4.216076e+11, 2.389698e+12, 4.447104e+12, 8.985233e+12, 8.393095e+11, 6.470177e+12, 1.345594e+13, 9.587181e+12, 1.271159e+13, 1.239322e+13, 5.868922e+12, 6.218498e+12]
list2 = [3.792533e+12, 8.696141e+12, 6.209372e+12, 2.436446e+12, 3.892219e+12, 6.200411e+12, 5.789223e+12, 1.972929e+13, 9.112180e+11, 8.959381e+12, 1.032237e+13, 1.401639e+13, 4.953527e+12, 6.504238e+12, 2.082973e+12, 6.495881e+12, 8.439209e+12, 8.296854e+12, 4.600647e+12, 7.547240e+12]

sns.histplot(list1, color='orange', label='Correlated', stat = "density")
sns.histplot(list2, color='blue', label="Independent", stat = "density").set(xlabel = 'Statistic', ylabel = 'repetitions', title = 'fascia runs')
plt.legend()
sns.set_style("darkgrid", {'ytick.left' : True, 'xtick.bottom': True, 'axes.spines.left': True, 'grid.color': '1', 'axes.edgecolor': '0', 'axes.spines.right': False, "axes.facecolor": ".9"})
sns.set_context("talk")
sns.despine(right = True, top=True)

# %%
# K=7 p = 0.5
curve = True
list1 = [4.177961e+15, 8.951627e+15, 3.633463e+15, 1.160430e+16, 4.309438e+15, 4.386283e+15, 6.708636e+15, 1.148798e+16, 7.479836e+14, 5.017676e+15, 1.570911e+16, 2.566493e+15, 1.961222e+16, 2.578651e+15, 1.801448e+16, 5.909801e+15, 1.337348e+16, 3.701078e+15, 4.443026e+15, 4.453506e+15]
list2 = [1.471571e+16, 3.848068e+15, -2.655455e+15, 8.140597e+15, 1.035384e+16, 3.979300e+14, 9.904801e+15, 1.640414e+16, 7.213373e+15, 3.228459e+15, 1.690190e+16, 1.158888e+16, 5.993542e+15, 3.545953e+15, 5.243466e+15, 1.107799e+16, 8.765563e+15, 3.252394e+15, 1.232939e+16, -1.198856e+14]

sns.histplot(list1, color='orange', label='Correlated', stat = "density")
sns.histplot(list2, color='blue', label="Independent", stat = "density").set(xlabel = 'Statistic', ylabel = 'repetitions', title = 'fascia runs')
plt.legend()
sns.set_style("darkgrid", {'ytick.left' : True, 'xtick.bottom': True, 'axes.spines.left': True, 'grid.color': '1', 'axes.edgecolor': '0', 'axes.spines.right': False, "axes.facecolor": ".9"})
sns.set_context("talk")
sns.despine(right = True, top=True)

# %%
'''
# facebook runs k = 6
curve = True
list1 = [5.06703e+06, 6.30917e+06, 5.39436e+06, 6.47958e+06, 5.26791e+06, 6.0579e+06, 7.62216e+06, 5.95662e+06, 5.07192e+06, 5.67897e+06, 6.13723e+09, 5.43592e+06, 6.22383e+06, 2.56824e+10, 4.64457e+09, 6.51761e+06, 4.70515e+06, 6.70929e+06, 6.67893e+06, 5.20769e+06, 6.23353e+06, 4.88701e+06, 9.7773e+10]
list2 = [4.75509e+06, 1.89211e+07, 5.8645e+06, 6.41865e+06, 9.05948e+06, 6.53754e+06, 7.37387e+06,7.89143e+06, 6.24858e+06, 1.87155e+06, 5.13922e+06, 6.45424e+06, 3.5234e+06, 6.4723e+06, 7.02223e+06, 6.96434e+06, 5.03053e+06, 6.26508e+06, 1.84697e+06, -4.61071e+07, -1.92234e+07, -1.01165e+07]
list3 = [3.46186e+07,6.99274e+06,8.67774e+06,8.29025e+06,7.36809e+07,2.05238e+10,5.34667e+06,9.39055e+08,3.63439e+08,8.20011e+06,4.14568e+06,6.15922e+06,6.54216e+06,6.66018e+06,7.55594e+06,6.86927e+06,6.78979e+06,5.43086e+06,8.41263e+09,6.84499e+06,6.08236e+06,8.27171e+06,4.69458e+06,5.00096e+06,5.30491e+08,1.50936e+10]

sns.histplot(list1, color='red', label='Northwestern', stat = "density")
sns.histplot(list3, color='yellow', label='UChicago', stat = "density")
sns.histplot(list2, color='blue', label="Both", stat = "density").set(xlabel = 
'Statistic', ylabel = 'count', title = 'fascia runs')
plt.legend()
sns.set_style("darkgrid", {'ytick.left' : True, 'xtick.bottom': True, 'axes.spines.left': True, 'grid.color': '1', 'axes.edgecolor': '0', 'axes.spines.right': False, "axes.facecolor": ".9"})
sns.set_context("talk")
sns.despine(right = True, top=True)
'''
# Out:
# '\n# facebook runs k = 6\ncurve = True\nlist1 = [5.06703e+06, 6.30917e+06, 5.39436e+06, 6.47958e+06, 5.26791e+06, 6.0579e+06, 7.62216e+06, 5.95662e+06, 5.07192e+06, 5.67897e+06, 6.13723e+09, 5.43592e+06, 6.22383e+06, 2.56824e+10, 4.64457e+09, 6.51761e+06, 4.70515e+06, 6.70929e+06, 6.67893e+06, 5.20769e+06, 6.23353e+06, 4.88701e+06, 9.7773e+10]\nlist2 = [4.75509e+06, 1.89211e+07, 5.8645e+06, 6.41865e+06, 9.05948e+06, 6.53754e+06, 7.37387e+06,7.89143e+06, 6.24858e+06, 1.87155e+06, 5.13922e+06, 6.45424e+06, 3.5234e+06, 6.4723e+06, 7.02223e+06, 6.96434e+06, 5.03053e+06, 6.26508e+06, 1.84697e+06, -4.61071e+07, -1.92234e+07, -1.01165e+07]\nlist3 = [3.46186e+07,6.99274e+06,8.67774e+06,8.29025e+06,7.36809e+07,2.05238e+10,5.34667e+06,9.39055e+08,3.63439e+08,8.20011e+06,4.14568e+06,6.15922e+06,6.54216e+06,6.66018e+06,7.55594e+06,6.86927e+06,6.78979e+06,5.43086e+06,8.41263e+09,6.84499e+06,6.08236e+06,8.27171e+06,4.69458e+06,5.00096e+06,5.30491e+08,1.50936e+10]\n\nsns.histplot(list1, color=\'red
# ...

# %%
#n = 10000, k = 6, p = 1/n m = will be 20, uncentered 

curve = True

correlated = [4.424969e+51,4.404769e+51,4.468189e+51,4.365793e+51,4.373572e+51,4.380689e+51,4.387120e+51,4.446061e+51,4.373189e+51,4.399050e+51]

independent = [4.384607e+51,4.438618e+51,4.422234e+51,4.399703e+51,4.408748e+51,4.413849e+51,4.396068e+51,4.396258e+51,4.384713e+51,4.413988e+51]

sns.histplot(correlated, color='orange', label='Correlated', stat = "density")
sns.histplot(independent, color='blue', label="Independent", stat = "density").set(xlabel = 'Statistic', ylabel = 'repetitions', title = 'fascia runs')
plt.legend()
sns.set_style("darkgrid", {'ytick.left' : True, 'xtick.bottom': True, 'axes.spines.left': True, 'grid.color': '1', 'axes.edgecolor': '0', 'axes.spines.right': False, "axes.facecolor": ".9"})
sns.set_context("talk")
sns.despine(right = True, top=True)

# %%
#n = 10000, k = 6, p = 1/n m = will be 20, centered 

curve = True

list1 = [1.172664e+16,1.273993e+16,1.292129e+16,1.310406e+16,1.206367e+16,1.356905e+16,1.245493e+16,1.306803e+16,1.244040e+16]

list2 = [1.275111e+16,1.282128e+16,1.320752e+16,1.183311e+16,1.307351e+16,1.312393e+16,1.280520e+16,1.217560e+16,1.240521e+16]

sns.histplot(list2, color='orange', label='Correlated', stat = "density")
sns.histplot(list1, color='blue', label="Independent", stat = "density").set(xlabel = 'Statistic', ylabel = 'repetitions', title = 'fascia runs')
plt.legend()
sns.set_style("darkgrid", {'ytick.left' : True, 'xtick.bottom': True, 'axes.spines.left': True, 'grid.color': '1', 'axes.edgecolor': '0', 'axes.spines.right': False, "axes.facecolor": ".9"})
sns.set_context("talk")
sns.despine(right = True, top=True)
